# %%
spark

# %%
data = data=([(1,'a'),(2,'b'),(3,'c')])
schema = "id int, value string"
df = spark.createDataFrame(data, schema)
df.show()

# %%
from datetime import datetime, date
import pandas as pd
from pyspark.sql import Row

df = spark.createDataFrame([
    Row(a=1, b=2., c='string1', d=date(2000, 1, 1), e=datetime(2000, 1, 1, 12, 0)),
    Row(a=2, b=3., c='string2', d=date(2000, 2, 1), e=datetime(2000, 1, 2, 12, 0)),
    Row(a=4, b=5., c='string3', d=date(2000, 3, 1), e=datetime(2000, 1, 3, 12, 0))
])
df.show()

# %% [markdown]
# ## Reader API

# %%
df_sales = spark.read.csv("/Volumes/acc_dev/naval/raw/csv/sales.csv", header=True, inferSchema=True)
df_sales.display()

# %%
df_sales.write.mode("overwrite").saveAsTable("acc_dev.karthik.sales_py")

# %%
spark.read.csv("/Volumes/acc_dev/naval/raw/csv/sales.csv", header=True, inferSchema=True).write.mode("overwrite").saveAsTable("acc_dev.karthik.sales_py")

# %%
# %sql
select * from acc_dev.karthik.sales_py

# %%
df_house_price = spark.read.parquet("/Volumes/acc_dev/naval/raw/house-price.parquet")
df_house_price.display()

# %%
df_house_price.write.mode("overwrite").saveAsTable("acc_dev.karthik.house_price")

# %%
# %sql
select * from acc_dev.karthik.house_price

# %%
df_orders = spark.read.json("/Volumes/acc_dev/naval/raw/retail_orders.json")
df_orders.show()
