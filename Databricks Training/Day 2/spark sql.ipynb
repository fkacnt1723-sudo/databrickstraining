# %%
# %sql
create or replace table acc_dev.karthik.house_price_parq as 
select *, current_date() as ingesteddate from parquet.`/Volumes/acc_dev/naval/raw/house-price.parquet`

# %%
# %sql
select * from acc_dev.karthik.house_price_parq
