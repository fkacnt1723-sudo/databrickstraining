# %% [markdown]
# Methods to Create a table
#
# 1. py_spark dataframe
# 2. CTAS
# 3. UI

# %%
# %sql
select * from acc_dev.karthik.sales limit 10;
select count(*) as num_rows_all_null from acc_dev.karthik.sales;

# %%
# %sql
select * from acc_dev.karthik.house_price;
