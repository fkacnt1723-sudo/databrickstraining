# %% [markdown]
# ## Databricks Notebooks

# %%
print("Hello World")

# %%
# %sql
SELECT 'HELLO WORLD'

# %%
# %sql
use catalog acc_dev;
create schema if not exists karthik;

# %%
# %sql
use catalog acc_dev;
use schema karthik;
create table if not exists acc_dev.karthik.demo_table (id int primary key, name string);

# %% [markdown]
# ![](/Volumes/acc_dev/naval/raw/object-model.png)
