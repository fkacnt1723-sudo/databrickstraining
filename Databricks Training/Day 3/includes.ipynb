# %%
# %python
from pyspark.sql.functions import *

# %%
# %python
input_path ="/Volumes/acc_dev/naval/raw/csv/"
file_name="housing"

# %%
# %sql
use catalog acc_dev;
create schema if not exists karthik_bronze;
create schema if not exists karthik_silver;
create schema if not exists karthik_gold;

# %%
# %python
def new_col(df):
    return df.withColumn("ingestion_date",current_timestamp()).withColumn("path",col("_metadata.file_path"))

# %%
# %python
catalog="acc_dev"
schema="karthik_bronze"
