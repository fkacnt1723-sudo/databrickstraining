# %%
# %run "/Workspace/Users/saikarthik3271@gmail.com/Databricks Training/Day 3/includes"

# %%
# read
df = spark.table(f"{catalog}.{schema}.sales")

# transform
df1 = df.dropDuplicates().dropna().drop("ingestion_date","path")

# write
df1.write.mode("overwrite").saveAsTable(f"{catalog}.karthik_silver.sales_cleaned")
