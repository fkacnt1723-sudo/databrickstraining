# %%
# %sql
use catalog acc_dev;
use schema karthik;

# %%
# %sql
create table if not exists emp(
  id int,
  name string,
  salary int
);

# %%
# %sql 
desc extended emp;

# %%
# %sql
insert into emp values (1, 'karthik', 20000);

# %%
# %sql
select * from emp;

# %%
# %sql 
desc history emp;

# %%
# %sql
insert into emp values (2, 'tanuja', 25000), (3, 'sai', 30000);

# %%
# %sql
delete from emp where id = 2;

# %%
# %sql
select * from emp;

# %%
# %sql
insert into acc_dev.naval.emp values (7, 'karthik', 'Atp');

# %%
# %sql 
delete from emp;

# %%
# %sql
restore table emp to version as of 3;
